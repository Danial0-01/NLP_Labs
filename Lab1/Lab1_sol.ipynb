# %%
import pandas as pd

streets = pd.read_csv("new_york_streets.csv")
streets.head(5)
# Out:
# C:\Users\dania\AppData\Local\Temp\ipykernel_9152\4128804034.py:3: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   streets = pd.read_csv("new_york_streets.csv")
#                              osmid  oneway        highway reversed   length  \
# 0                         25161578    True  motorway_link    False  254.709
# 1            [122633397, 25161349]    True       motorway    False  767.800
# 2                          5699971    True  motorway_link    False  259.674
# 3                       1014007069    True       motorway    False  291.839
# 4  [618709517, 618709515, 5700693]    True  motorway_link    False  433.148
#
#                                             geometry lanes  ref  \
# 0  LINESTRING (-73.7946273 40.7864093, -73.793612...   NaN  NaN
# 1  LINESTRING (-73.7946273 40.7864093, -73.793086...     2   CI
# 2  LINESTRING (-73.7570906 40.7624294, -73.757209...   NaN  NaN
# ...
