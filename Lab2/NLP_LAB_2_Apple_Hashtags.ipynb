# %% [markdown]
# #Lab2: Text Pre-processing and Regular Expressions

# %% [markdown]
#  In this lab, you will learn essential techniques for preparing and cleaning text data using various pre-processing steps. Additionally, you will gain hands-on experience with regular expressions, a powerful tool for pattern matching and text manipulation in natural language processing (NLP) tasks.

# %% [markdown]
# _____________________________________________________________________________________________

# %% [markdown]
# ## Regular Expressions

# %% [markdown]
# Regular expressions (regex) are extremely useful in extracting information from any text by searching for one or more matches of a specific search pattern
#
# https://www.regexpal.com/

# %% [markdown]
# #### Regular Expressions use cases
#
# - Data pre-processing
# - Pattern matching
# - Text feature Engineering
# - Web scraping
# - Data validation
# - Data extraction
#
# An example use case is extracting all hashtags from a tweet, or getting email addresses or phone numbers from large unstructured text content.

# %% [markdown]
# ## Regular Expressions with Python
#
# Python provides a convenient built-in module for managing regular expressions:
#
# > import re
#
# We can import it as we import any other Python library.

# %% [markdown]
# ### Important symbols in Regular Expression
#
# Let’s start with the basic regular expression characters and some examples:
#
# - (^) : Matches the expression to its right, at the start of a string before it finds a line break.
# - ($) : Matches the expression to its left, at the end of a string before it finds a line break.
# - (.) : Matches any character except newline.
# - (a) : Matches exactly one character.
# - (ab) : Matches the string ab.
#
# ----------------------------------------------------------------------------
# Quantifiers:
#
# - (a|b) : Matches expression a or b. If a is matched first, b is not checked;
# - (+) : Matches the expression to its left 1 or more times;
# - (*) : Matches the expression to its left 0 or more times;
# - (?) : Matches the expression to its left 0 or 1 times.
# ----------------------------------------------------------------------------
# Character Classes:
#
# - \w : Matches alphanumeric characters, that is a-z, A-Z, 0–9, and underscore(_);
# - \W : Matches non-alphanumeric characters, that is except a-z, A-Z, 0–9, and _;
# - \d : Matches digits, from 0–9;
# - \D : Matches any non-digits;
# - \s : Matches whitespace characters, which also include the \t, \n, \r, and space characters;
# - \S : Matches non-whitespace characters.
# - \n : Matches a newline character;
# - \t : Matches a tab character;
# - \b : Matches the word boundary (or empty string) at the start and end of a word;
# - \B : Matches where \b does not, that is non-word boundary.
#
# ----------------------------------------------------------------------------
# Sets:
#
# - [abc] : Matches either a, b, or c. It does not match abc;
# - [a-z] : Matches any alphabet from a to z;
# - [A-Z] : Matches any alphabets in capital from A to Z;
# - [a\-p] : Matches a, -, or p. It matches - because \ escapes it;
# - [-z] : Matches - or z;
# - [a-z0–9] : Matches characters from a to z or from 0 to 9.
# - [(+*)] : Special characters become literal inside a set, so this matches (, +, *, or );
# - [^ab5] : Adding ^ excludes any character in the set. Here, it matches characters that are not a, b, or 5;
# ----------------------------------------------------------------------------
#
#
# ### Regular Expression functions

# %% [markdown]
# #### search
#
# Search for pattern occurrences in a string using the search function of the **re module**. This function returns a match object, containing the matched substring (or None, if it doesn’t exist) and its position inside the original string.

# %%
import re

text = 'I am enjoying the NLP course.'

print(re.search(r"I", text)) #r is maning i will start regular
print(re.search(r"se.$", text)) #$ look form the end
print(re.search(r"am", text))
print(re.search(r"m", text))
print(re.search(r"AI", text))
# Out:
# <re.Match object; span=(0, 1), match='I'>
# <re.Match object; span=(26, 29), match='se.'>
# <re.Match object; span=(2, 4), match='am'>
# <re.Match object; span=(3, 4), match='m'>
# None

# %%
match = re.search((r"I"),text)
print(match.span())
print(match.start())
print(match.end())
print("The matched pattern is: ",text[match.start():match.end()]) #index from text
# Out:
# (0, 1)
# 0
# 1
# The matched pattern is:  I

# %% [markdown]
# #### match
#
# The match function is similar to search, but it only tries to match the pattern at the beginning of the target string.

# %%
import re

text = 'I am enjoying the NLP course.'

print(re.search(r"I.*", text)) #globel
print(re.match(r"I.*", text)) #local >> see the start word

print(re.search(r"enjoying.*", text))
print(re.match(r"enjoying.*", text))
# Out:
# <re.Match object; span=(0, 29), match='I am enjoying the NLP course.'>
# <re.Match object; span=(0, 29), match='I am enjoying the NLP course.'>
# <re.Match object; span=(5, 29), match='enjoying the NLP course.'>
# None

# %%
import re

text = '1999 was the year I was born.'

print(re.search(r"[a-zA-Z]+", text))
print(re.match(r"[a-zA-Z]+", text))
# Out:
# <re.Match object; span=(5, 8), match='was'>
# None

# %% [markdown]
# Search does a global search, whereas match does a local search!
#
# **Match** is often used when you need to check if the string starts with a specific pattern.
#
#
# **Search** is used when you want to find a pattern anywhere within the string.

# %% [markdown]
# #### findall
#
# The findall function looks for all the pattern matches in the target string (whereas search and match look only for the first occurrence). The former returns a list, and the latter returns an iterator.

# %%
import re

text1 = "a 1 b 2 c 3"
text2 = "a1 b2 c 3"
text3 = "a 1 b 222 c 3"

print(re.findall(r"\d+", text1)) #match any letter or digit
print(re.findall(r"\d+", text2))
print(re.findall(r"\d+", text3))
# Out:
# ['1', '2', '3']
# ['1', '2', '3']
# ['1', '222', '3']

# %% [markdown]
# #### sub
#
# The sub is a function that finds patterns in the target string and substitute them with another string.
#
# flags=re.I --> non-case-sensitive
#
# count = specify number of matches you want to replace

# %%
import re

text = 'I am enjoying the Math course.'

print(re.sub(r"Math", "NLP", text,1,flags=re.I)) #flags=re.I >> not mater if M or m
                                                 # 1 >> number of word i need it to change
# Out:
# I am enjoying the NLP course.

# %% [markdown]
# #### compile
#
# The compile function compiles a regular expression into a regular expression object, which allows for caching and faster pattern matching.

# %%
import re

text = "This year is 2021"
pattern = re.compile(r"\d+")

print(pattern.sub("2022", text))
# Out:
# This year is 2022

# %% [markdown]
# #### split
#
# The split function is similar to the Python split function, but splits according to regular expression patterns.

# %%
import re

text = "a 1 b 2 c 3"

print(re.split(r"\d+", text))
# Out:
# ['a ', ' b ', ' c ', '']

# %% [markdown]
# __________________________________________________________________________

# %% [markdown]
# ## Text pre-processing steps

# %% [markdown]
# Text preprocessing involves transforming text into a clean and consistent format that can then be fed into a model for further analysis and learning. Raw text data might contain unwanted or unimportant text due to which our results might not give efficient accuracy, and might make it hard to understand and analyze.

# %% [markdown]
# **The various text preprocessing steps are:**
#
# 1. Tokenization.
# 2. Lower casing.
# 3. Stop words removal.
# 4. Stemming.
# 5. Lemmatization.
#
# Before implementing the pre-processing, let us understand the concept first.

# %% [markdown]
# ### Tokenization
#
# Tokenization is used in NLP to split paragraphs and sentences into smaller units that can be more easily assigned meaning.
#
# The first step of the NLP process is gathering the data (a sentence) and breaking it into understandable parts (words).

# %% [markdown]
# - **Sentance Tokenization**

# %%
# %pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (3.10.3)
# Requirement already satisfied: defusedxml in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from nltk) (0.7.1)
# Requirement already satisfied: click in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from nltk) (8.4.1)
# Requirement already satisfied: joblib in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from nltk) (2026.9.10)
# Requirement already satisfied: tqdm in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from nltk) (4.70.1)
# Requirement already satisfied: colorama in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk
nltk.download('punkt_tab', quiet=True)

text = "I'm enjoying the NLP course! I am also learning new concepts."

print(nltk.sent_tokenize(text)) #base on . >> which is the end of sentencce
# Out:
# ["I'm enjoying the NLP course!", 'I am also learning new concepts.']

# %% [markdown]
# - **Word Tokenzitaion**

# %%
text = "I'm enjoying the NLP course!"
text.split()
# Out:
# ["I'm", 'enjoying', 'the', 'NLP', 'course!']

# %%
import nltk

text = "I'm enjoying the NLP course!"

print(nltk.word_tokenize(text))
# Out:
# ['I', "'m", 'enjoying', 'the', 'NLP', 'course', '!']

# %%
# %pip install -U spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (3.8.16)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from spacy) (0.27.2)
# Requirement already satisfied: click<9.0.0,>=8.2.1 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from spacy) (8.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from spacy) (4.70.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.4.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.34.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.13.5)
# Requirement already satisfied: jinja2 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from spacy) (84.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from spacy) (26.2)
# Requirement already satisfied: colorama in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from click<9.0.0,>=8.2.1->spacy) (0.4.6)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.46.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.17)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.5.20)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.5)
# Requirement already satisfied: cloudpathlib>=0.7.0 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.25.0)
# Requirement already satisfied: smart-open>=5.2.1 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (8.0.1)
# Requirement already satisfied: httpx>=0.24.0 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from jinja2->spacy) (3.0.3)
# Requirement already satisfied: anyio in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.13.0)
# Requirement already satisfied: httpcore==1.* in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dania\appdata\roaming\python\python312\site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (2.20.0)
# Requirement already satisfied: wrapt in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.4.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dania\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.1/12.8 MB 1.7 MB/s eta 0:00:08
#       --------------------------------------- 0.2/12.8 MB 2.6 MB/s eta 0:00:05
#       --------------------------------------- 0.2/12.8 MB 1.4 MB/s eta 0:00:10
#       --------------------------------------- 0.3/12.8 MB 1.3 MB/s eta 0:00:10
#       --------------------------------------- 0.3/12.8 MB 1.3 MB/s eta 0:00:10
#      - -------------------------------------- 0.3/12.8 MB 1.2 MB/s eta 0:00:11
#      - -------------------------------------- 0.4/12.8 MB 1.2 MB/s eta 0:00:11
#      - -------------------------------------- 0.4/12.8 MB 1.3 MB/s eta 0:00:10
#      - -------------------------------------- 0.5/12.8 MB 1.3 MB/s eta 0:00:10
#      - -------------------------------------- 0.6/12.8 MB 1.2 MB/s eta 0:00:10
#      - -------------------------------------- 0.6/12.8 MB 1.3 MB/s eta 0:00:10
#      -- ------------------------------------- 0.6/12.8 MB 1.3 MB/s eta 0:00:10
#      -- ------------------------------------- 0.7/12.8 MB 1.2 MB/s eta 0:00:10
#      -- ------------------------------------- 0.8/12.8 MB 1.3 MB/s eta 0:00:10
#      -- ------------------------------------- 0.8/12.8 MB 1.2 MB/s eta 0:00:11
#      -- ------------------------------------- 0.8/12.8 MB 1.2 MB/s eta 0:00:11
#      -- ------------------------------------- 0.9/12.8 MB 1.1 MB/s eta 0:00:11
#      -- ------------------------------------- 0.9/12.8 MB 1.1 MB/s eta 0:00:11
#      -- ------------------------------------- 1.0/12.8 MB 1.1 MB/s eta 0:00:11
#      --- ------------------------------------ 1.0/12.8 MB 1.1 MB/s eta 0:00:11
#      --- ------------------------------------ 1.0/12.8 MB 1.1 MB/s eta 0:00:11
#      --- ------------------------------------ 1.1/12.8 MB 1.1 MB/s eta 0:00:11
#      --- ------------------------------------ 1.1/12.8 MB 1.1 MB/s eta 0:00:11
#      --- ------------------------------------ 1.2/12.8 MB 1.1 MB/s eta 0:00:11
#      --- ------------------------------------ 1.2/12.8 MB 1.1 MB/s eta 0:00:11
#      --- ------------------------------------ 1.2/12.8 MB 1.1 MB/s eta 0:00:11
#      --- ------------------------------------ 1.3/12.8 MB 1.1 MB/s eta 0:00:11
#      ---- ----------------------------------- 1.3/12.8 MB 1.1 MB/s eta 0:00:11
#      ---- ----------------------------------- 1.4/12.8 MB 1.0 MB/s eta 0:00:11
#      ---- ----------------------------------- 1.4/12.8 MB 1.0 MB/s eta 0:00:11
#      ---- ----------------------------------- 1.5/12.8 MB 1.0 MB/s eta 0:00:11
#      ---- ----------------------------------- 1.5/12.8 MB 1.0 MB/s eta 0:00:11
#      ---- ----------------------------------- 1.5/12.8 MB 1.0 MB/s eta 0:00:11
#      ---- ----------------------------------- 1.5/12.8 MB 1.0 MB/s eta 0:00:11
#      ----- ---------------------------------- 1.6/12.8 MB 1.0 MB/s eta 0:00:11
#      ----- ---------------------------------- 1.7/12.8 MB 1.0 MB/s eta 0:00:12
#      ----- ---------------------------------- 1.7/12.8 MB 1.0 MB/s eta 0:00:12
#      ----- ---------------------------------- 1.8/12.8 MB 1.0 MB/s eta 0:00:12
#      ----- --------------------------------- 1.8/12.8 MB 997.2 kB/s eta 0:00:12
#      ----- --------------------------------- 1.8/12.8 MB 994.0 kB/s eta 0:00:12
#      ----- --------------------------------- 1.9/12.8 MB 983.2 kB/s eta 0:00:12
#      ----- --------------------------------- 1.9/12.8 MB 980.5 kB/s eta 0:00:12
#      ------ -------------------------------- 2.0/12.8 MB 990.5 kB/s eta 0:00:11
#      ------ -------------------------------- 2.0/12.8 MB 983.2 kB/s eta 0:00:11
#      ------ -------------------------------- 2.1/12.8 MB 992.7 kB/s eta 0:00:11
#      ------ -------------------------------- 2.1/12.8 MB 987.9 kB/s eta 0:00:11
#      ------ -------------------------------- 2.2/12.8 MB 982.8 kB/s eta 0:00:11
#      ------ -------------------------------- 2.2/12.8 MB 990.1 kB/s eta 0:00:11
#      ------ -------------------------------- 2.2/12.8 MB 985.1 kB/s eta 0:00:11
#      ------ -------------------------------- 2.3/12.8 MB 985.2 kB/s eta 0:00:11
#      ------ -------------------------------- 2.3/12.8 MB 980.9 kB/s eta 0:00:11
#      ------- ------------------------------- 2.3/12.8 MB 972.2 kB/s eta 0:00:11
#      ------- ------------------------------- 2.4/12.8 MB 974.4 kB/s eta 0:00:11
#      ------- ------------------------------- 2.4/12.8 MB 976.6 kB/s eta 0:00:11
#      ------- ------------------------------- 2.5/12.8 MB 976.8 kB/s eta 0:00:11
#      ------- ------------------------------- 2.5/12.8 MB 983.1 kB/s eta 0:00:11
#      ------- ------------------------------- 2.5/12.8 MB 971.1 kB/s eta 0:00:11
#      ------- ------------------------------- 2.6/12.8 MB 973.2 kB/s eta 0:00:11
#      -------- ------------------------------ 2.6/12.8 MB 975.2 kB/s eta 0:00:11
#      -------- ------------------------------ 2.7/12.8 MB 973.5 kB/s eta 0:00:11
#      -------- ------------------------------ 2.7/12.8 MB 977.4 kB/s eta 0:00:11
#      -------- ------------------------------ 2.8/12.8 MB 979.2 kB/s eta 0:00:11
#      -------- ------------------------------ 2.8/12.8 MB 977.5 kB/s eta 0:00:11
#      -------- ------------------------------ 2.8/12.8 MB 972.6 kB/s eta 0:00:11
#      -------- ------------------------------ 2.9/12.8 MB 974.4 kB/s eta 0:00:11
#      -------- ------------------------------ 2.9/12.8 MB 964.2 kB/s eta 0:00:11
#      --------- ----------------------------- 3.0/12.8 MB 962.8 kB/s eta 0:00:11
#      --------- ----------------------------- 3.0/12.8 MB 961.4 kB/s eta 0:00:11
#      --------- ----------------------------- 3.0/12.8 MB 955.6 kB/s eta 0:00:11
#      --------- ----------------------------- 3.1/12.8 MB 960.7 kB/s eta 0:00:11
#      --------- ----------------------------- 3.2/12.8 MB 958.1 kB/s eta 0:00:11
#      --------- ----------------------------- 3.2/12.8 MB 958.2 kB/s eta 0:00:11
#      --------- ----------------------------- 3.2/12.8 MB 960.0 kB/s eta 0:00:10
#      --------- ----------------------------- 3.3/12.8 MB 954.6 kB/s eta 0:00:10
#      ---------- ---------------------------- 3.3/12.8 MB 947.5 kB/s eta 0:00:11
#      ---------- ---------------------------- 3.3/12.8 MB 949.4 kB/s eta 0:00:10
#      ---------- ---------------------------- 3.4/12.8 MB 949.8 kB/s eta 0:00:10
#      ---------- ---------------------------- 3.4/12.8 MB 947.3 kB/s eta 0:00:10
#      ---------- ---------------------------- 3.5/12.8 MB 941.1 kB/s eta 0:00:10
#      ---------- ---------------------------- 3.5/12.8 MB 937.4 kB/s eta 0:00:10
#      ---------- ---------------------------- 3.5/12.8 MB 933.9 kB/s eta 0:00:10
#      ---------- ---------------------------- 3.5/12.8 MB 934.4 kB/s eta 0:00:10
#      ---------- ---------------------------- 3.6/12.8 MB 930.9 kB/s eta 0:00:10
#      ----------- --------------------------- 3.6/12.8 MB 926.4 kB/s eta 0:00:10
#      ----------- --------------------------- 3.6/12.8 MB 923.1 kB/s eta 0:00:10
#      ----------- --------------------------- 3.7/12.8 MB 917.4 kB/s eta 0:00:10
#      ----------- --------------------------- 3.7/12.8 MB 917.4 kB/s eta 0:00:10
#      ----------- --------------------------- 3.7/12.8 MB 912.4 kB/s eta 0:00:10
#      ----------- --------------------------- 3.7/12.8 MB 906.1 kB/s eta 0:00:10
#      ----------- --------------------------- 3.8/12.8 MB 904.3 kB/s eta 0:00:10
#      ----------- --------------------------- 3.8/12.8 MB 899.8 kB/s eta 0:00:11
#      ----------- --------------------------- 3.8/12.8 MB 893.9 kB/s eta 0:00:11
#      ----------- --------------------------- 3.9/12.8 MB 883.8 kB/s eta 0:00:11
#      ----------- --------------------------- 3.9/12.8 MB 880.7 kB/s eta 0:00:11
#      ------------ -------------------------- 3.9/12.8 MB 873.8 kB/s eta 0:00:11
#      ------------ -------------------------- 4.0/12.8 MB 868.5 kB/s eta 0:00:11
#      ------------ -------------------------- 4.0/12.8 MB 870.1 kB/s eta 0:00:11
#      ------------ -------------------------- 4.0/12.8 MB 866.5 kB/s eta 0:00:11
#      ------------ -------------------------- 4.1/12.8 MB 860.0 kB/s eta 0:00:11
#      ------------ -------------------------- 4.1/12.8 MB 861.5 kB/s eta 0:00:11
#      ------------ -------------------------- 4.1/12.8 MB 856.7 kB/s eta 0:00:11
#      ------------ -------------------------- 4.1/12.8 MB 855.3 kB/s eta 0:00:11
#      ------------ -------------------------- 4.2/12.8 MB 850.7 kB/s eta 0:00:11
#      ------------ -------------------------- 4.2/12.8 MB 852.1 kB/s eta 0:00:11
#      ------------ -------------------------- 4.2/12.8 MB 847.6 kB/s eta 0:00:11
#      ------------ -------------------------- 4.2/12.8 MB 847.9 kB/s eta 0:00:11
#      ------------- ------------------------- 4.3/12.8 MB 846.7 kB/s eta 0:00:11
#      ------------- ------------------------- 4.4/12.8 MB 844.5 kB/s eta 0:00:11
#      ------------- ------------------------- 4.4/12.8 MB 837.8 kB/s eta 0:00:11
#      ------------- ------------------------- 4.4/12.8 MB 836.2 kB/s eta 0:00:11
#      ------------- ------------------------- 4.4/12.8 MB 834.5 kB/s eta 0:00:11
#      ------------- ------------------------- 4.5/12.8 MB 831.0 kB/s eta 0:00:11
#      ------------- ------------------------- 4.5/12.8 MB 832.0 kB/s eta 0:00:10
#      ------------- ------------------------- 4.5/12.8 MB 832.0 kB/s eta 0:00:10
#      ------------- ------------------------- 4.5/12.8 MB 823.3 kB/s eta 0:00:11
#      ------------- ------------------------- 4.6/12.8 MB 822.0 kB/s eta 0:00:11
#      ------------- ------------------------- 4.6/12.8 MB 818.8 kB/s eta 0:00:11
#      -------------- ------------------------ 4.6/12.8 MB 820.1 kB/s eta 0:00:11
#      -------------- ------------------------ 4.6/12.8 MB 818.7 kB/s eta 0:00:10
#      -------------- ------------------------ 4.6/12.8 MB 811.1 kB/s eta 0:00:11
#      -------------- ------------------------ 4.7/12.8 MB 812.4 kB/s eta 0:00:11
#      -------------- ------------------------ 4.7/12.8 MB 807.3 kB/s eta 0:00:11
#      -------------- ------------------------ 4.7/12.8 MB 809.0 kB/s eta 0:00:11
#      -------------- ------------------------ 4.7/12.8 MB 803.5 kB/s eta 0:00:11
#      -------------- ------------------------ 4.8/12.8 MB 806.2 kB/s eta 0:00:10
#      -------------- ------------------------ 4.8/12.8 MB 805.0 kB/s eta 0:00:10
#      -------------- ------------------------ 4.8/12.8 MB 803.8 kB/s eta 0:00:10
#      -------------- ------------------------ 4.9/12.8 MB 802.2 kB/s eta 0:00:10
#      -------------- ------------------------ 4.9/12.8 MB 801.5 kB/s eta 0:00:10
#      --------------- ----------------------- 4.9/12.8 MB 798.4 kB/s eta 0:00:10
#      --------------- ----------------------- 4.9/12.8 MB 799.7 kB/s eta 0:00:10
#      --------------- ----------------------- 5.0/12.8 MB 798.2 kB/s eta 0:00:10
#      --------------- ----------------------- 5.0/12.8 MB 800.8 kB/s eta 0:00:10
#      --------------- ----------------------- 5.1/12.8 MB 797.8 kB/s eta 0:00:10
#      --------------- ----------------------- 5.1/12.8 MB 796.7 kB/s eta 0:00:10
#      --------------- ----------------------- 5.1/12.8 MB 797.7 kB/s eta 0:00:10
#      --------------- ----------------------- 5.1/12.8 MB 796.9 kB/s eta 0:00:10
#      --------------- ----------------------- 5.2/12.8 MB 797.1 kB/s eta 0:00:10
#      --------------- ----------------------- 5.2/12.8 MB 794.9 kB/s eta 0:00:10
#      --------------- ----------------------- 5.2/12.8 MB 794.9 kB/s eta 0:00:10
#      ---------------- ---------------------- 5.3/12.8 MB 792.6 kB/s eta 0:00:10
#      ---------------- ---------------------- 5.3/12.8 MB 790.4 kB/s eta 0:00:10
#      ---------------- ---------------------- 5.3/12.8 MB 791.6 kB/s eta 0:00:10
#      ---------------- ---------------------- 5.3/12.8 MB 788.9 kB/s eta 0:00:10
#      ---------------- ---------------------- 5.4/12.8 MB 787.9 kB/s eta 0:00:10
#      ---------------- ---------------------- 5.4/12.8 MB 785.5 kB/s eta 0:00:10
#      ---------------- ---------------------- 5.4/12.8 MB 784.6 kB/s eta 0:00:10
#      ---------------- ---------------------- 5.4/12.8 MB 783.7 kB/s eta 0:00:10
#      ---------------- ---------------------- 5.5/12.8 MB 782.8 kB/s eta 0:00:10
#      ---------------- ---------------------- 5.5/12.8 MB 783.8 kB/s eta 0:00:10
#      ---------------- ---------------------- 5.5/12.8 MB 783.2 kB/s eta 0:00:10
#      ---------------- ---------------------- 5.6/12.8 MB 780.6 kB/s eta 0:00:10
#      ---------------- ---------------------- 5.6/12.8 MB 778.6 kB/s eta 0:00:10
#      ----------------- --------------------- 5.6/12.8 MB 777.6 kB/s eta 0:00:10
#      ----------------- --------------------- 5.6/12.8 MB 776.8 kB/s eta 0:00:10
#      ----------------- --------------------- 5.7/12.8 MB 773.2 kB/s eta 0:00:10
#      ----------------- --------------------- 5.7/12.8 MB 772.2 kB/s eta 0:00:10
#      ----------------- --------------------- 5.7/12.8 MB 772.2 kB/s eta 0:00:10
#      ----------------- --------------------- 5.8/12.8 MB 768.4 kB/s eta 0:00:10
#      ----------------- --------------------- 5.8/12.8 MB 768.0 kB/s eta 0:00:10
#      ----------------- --------------------- 5.8/12.8 MB 765.6 kB/s eta 0:00:10
#      ----------------- --------------------- 5.9/12.8 MB 764.8 kB/s eta 0:00:10
#      ----------------- --------------------- 5.9/12.8 MB 765.9 kB/s eta 0:00:10
#      ------------------ -------------------- 5.9/12.8 MB 765.0 kB/s eta 0:00:09
#      ------------------ -------------------- 5.9/12.8 MB 765.0 kB/s eta 0:00:09
#      ------------------ -------------------- 5.9/12.8 MB 765.0 kB/s eta 0:00:09
#      ------------------ -------------------- 5.9/12.8 MB 765.0 kB/s eta 0:00:09
#      ------------------ -------------------- 6.0/12.8 MB 752.1 kB/s eta 0:00:10
#      ------------------ -------------------- 6.0/12.8 MB 750.4 kB/s eta 0:00:10
#      ------------------ -------------------- 6.0/12.8 MB 749.9 kB/s eta 0:00:10
#      ------------------ -------------------- 6.1/12.8 MB 752.1 kB/s eta 0:00:09
#      ------------------ -------------------- 6.1/12.8 MB 751.5 kB/s eta 0:00:09
#      ------------------ -------------------- 6.1/12.8 MB 750.8 kB/s eta 0:00:09
#      ------------------ -------------------- 6.2/12.8 MB 751.3 kB/s eta 0:00:09
#      ------------------ -------------------- 6.2/12.8 MB 751.1 kB/s eta 0:00:09
#      ------------------- ------------------- 6.3/12.8 MB 751.3 kB/s eta 0:00:09
#      ------------------- ------------------- 6.3/12.8 MB 749.6 kB/s eta 0:00:09
#      ------------------- ------------------- 6.3/12.8 MB 749.3 kB/s eta 0:00:09
#      ------------------- ------------------- 6.3/12.8 MB 750.2 kB/s eta 0:00:09
#      ------------------- ------------------- 6.3/12.8 MB 750.2 kB/s eta 0:00:09
#      ------------------- ------------------- 6.3/12.8 MB 744.3 kB/s eta 0:00:09
#      ------------------- ------------------- 6.4/12.8 MB 742.8 kB/s eta 0:00:09
#      ------------------- ------------------- 6.4/12.8 MB 743.7 kB/s eta 0:00:09
#      ------------------- ------------------- 6.4/12.8 MB 741.8 kB/s eta 0:00:09
#      ------------------- ------------------- 6.4/12.8 MB 740.2 kB/s eta 0:00:09
#      ------------------- ------------------- 6.5/12.8 MB 738.7 kB/s eta 0:00:09
#      ------------------- ------------------- 6.5/12.8 MB 738.7 kB/s eta 0:00:09
#      ------------------- ------------------- 6.5/12.8 MB 736.7 kB/s eta 0:00:09
#      ------------------- ------------------- 6.5/12.8 MB 736.7 kB/s eta 0:00:09
#      ------------------- ------------------- 6.5/12.8 MB 731.3 kB/s eta 0:00:09
#      ------------------- ------------------- 6.6/12.8 MB 730.9 kB/s eta 0:00:09
#      ------------------- ------------------- 6.6/12.8 MB 730.9 kB/s eta 0:00:09
#      -------------------- ------------------ 6.6/12.8 MB 725.5 kB/s eta 0:00:09
#      -------------------- ------------------ 6.6/12.8 MB 721.6 kB/s eta 0:00:09
#      -------------------- ------------------ 6.6/12.8 MB 721.6 kB/s eta 0:00:09
#      -------------------- ------------------ 6.6/12.8 MB 720.2 kB/s eta 0:00:09
#      -------------------- ------------------ 6.6/12.8 MB 720.2 kB/s eta 0:00:09
#      -------------------- ------------------ 6.6/12.8 MB 715.0 kB/s eta 0:00:09
#      -------------------- ------------------ 6.6/12.8 MB 713.7 kB/s eta 0:00:09
#      -------------------- ------------------ 6.6/12.8 MB 713.7 kB/s eta 0:00:09
#      -------------------- ------------------ 6.7/12.8 MB 708.8 kB/s eta 0:00:09
#      -------------------- ------------------ 6.7/12.8 MB 708.8 kB/s eta 0:00:09
#      -------------------- ------------------ 6.7/12.8 MB 702.8 kB/s eta 0:00:09
#      -------------------- ------------------ 6.7/12.8 MB 701.6 kB/s eta 0:00:09
#      -------------------- ------------------ 6.7/12.8 MB 699.2 kB/s eta 0:00:09
#      -------------------- ------------------ 6.7/12.8 MB 699.2 kB/s eta 0:00:09
#      -------------------- ------------------ 6.7/12.8 MB 695.5 kB/s eta 0:00:09
#      -------------------- ------------------ 6.8/12.8 MB 693.2 kB/s eta 0:00:09
#      -------------------- ------------------ 6.8/12.8 MB 692.0 kB/s eta 0:00:09
#      -------------------- ------------------ 6.8/12.8 MB 690.8 kB/s eta 0:00:09
#      -------------------- ------------------ 6.8/12.8 MB 690.8 kB/s eta 0:00:09
#      -------------------- ------------------ 6.8/12.8 MB 687.3 kB/s eta 0:00:09
#      -------------------- ------------------ 6.8/12.8 MB 687.3 kB/s eta 0:00:09
#      -------------------- ------------------ 6.9/12.8 MB 685.1 kB/s eta 0:00:09
#      -------------------- ------------------ 6.9/12.8 MB 684.0 kB/s eta 0:00:09
#      -------------------- ------------------ 6.9/12.8 MB 681.7 kB/s eta 0:00:09
#      --------------------- ----------------- 6.9/12.8 MB 680.6 kB/s eta 0:00:09
#      --------------------- ----------------- 6.9/12.8 MB 678.4 kB/s eta 0:00:09
#      --------------------- ----------------- 6.9/12.8 MB 678.4 kB/s eta 0:00:09
#      --------------------- ----------------- 7.0/12.8 MB 675.2 kB/s eta 0:00:09
#      --------------------- ----------------- 7.0/12.8 MB 675.2 kB/s eta 0:00:09
#      --------------------- ----------------- 7.0/12.8 MB 673.1 kB/s eta 0:00:09
#      --------------------- ----------------- 7.0/12.8 MB 671.0 kB/s eta 0:00:09
#      --------------------- ----------------- 7.0/12.8 MB 669.0 kB/s eta 0:00:09
#      --------------------- ----------------- 7.1/12.8 MB 668.9 kB/s eta 0:00:09
#      --------------------- ----------------- 7.1/12.8 MB 668.9 kB/s eta 0:00:09
#      --------------------- ----------------- 7.1/12.8 MB 666.9 kB/s eta 0:00:09
#      --------------------- ----------------- 7.1/12.8 MB 665.9 kB/s eta 0:00:09
#      --------------------- ----------------- 7.1/12.8 MB 666.8 kB/s eta 0:00:09
#      --------------------- ----------------- 7.2/12.8 MB 664.9 kB/s eta 0:00:09
#      --------------------- ----------------- 7.2/12.8 MB 663.9 kB/s eta 0:00:09
#      --------------------- ----------------- 7.2/12.8 MB 662.9 kB/s eta 0:00:09
#      ---------------------- ---------------- 7.2/12.8 MB 662.9 kB/s eta 0:00:09
#      ---------------------- ---------------- 7.3/12.8 MB 661.9 kB/s eta 0:00:09
#      ---------------------- ---------------- 7.3/12.8 MB 661.8 kB/s eta 0:00:09
#      ---------------------- ---------------- 7.3/12.8 MB 661.8 kB/s eta 0:00:09
#      ---------------------- ---------------- 7.3/12.8 MB 660.9 kB/s eta 0:00:09
#      ---------------------- ---------------- 7.4/12.8 MB 660.9 kB/s eta 0:00:09
#      ---------------------- ---------------- 7.4/12.8 MB 660.9 kB/s eta 0:00:09
#      ---------------------- ---------------- 7.4/12.8 MB 659.0 kB/s eta 0:00:09
#      ---------------------- ---------------- 7.4/12.8 MB 659.0 kB/s eta 0:00:09
#      ---------------------- ---------------- 7.4/12.8 MB 657.2 kB/s eta 0:00:09
#      ---------------------- ---------------- 7.5/12.8 MB 657.1 kB/s eta 0:00:09
#      ---------------------- ---------------- 7.5/12.8 MB 656.3 kB/s eta 0:00:09
#      ---------------------- ---------------- 7.5/12.8 MB 655.3 kB/s eta 0:00:09
#      ---------------------- ---------------- 7.5/12.8 MB 654.4 kB/s eta 0:00:09
#      ---------------------- ---------------- 7.5/12.8 MB 654.4 kB/s eta 0:00:09
#      ----------------------- --------------- 7.6/12.8 MB 652.7 kB/s eta 0:00:09
#      ----------------------- --------------- 7.6/12.8 MB 653.6 kB/s eta 0:00:08
#      ----------------------- --------------- 7.6/12.8 MB 651.8 kB/s eta 0:00:09
#      ----------------------- --------------- 7.6/12.8 MB 651.8 kB/s eta 0:00:08
#      ----------------------- --------------- 7.6/12.8 MB 651.0 kB/s eta 0:00:08
#      ----------------------- --------------- 7.7/12.8 MB 650.2 kB/s eta 0:00:08
#      ----------------------- --------------- 7.7/12.8 MB 651.0 kB/s eta 0:00:08
#      ----------------------- --------------- 7.7/12.8 MB 651.0 kB/s eta 0:00:08
#      ----------------------- --------------- 7.8/12.8 MB 650.2 kB/s eta 0:00:08
#      ----------------------- --------------- 7.8/12.8 MB 650.2 kB/s eta 0:00:08
#      ----------------------- --------------- 7.8/12.8 MB 649.4 kB/s eta 0:00:08
#      ----------------------- --------------- 7.9/12.8 MB 649.4 kB/s eta 0:00:08
#      ------------------------ -------------- 7.9/12.8 MB 650.3 kB/s eta 0:00:08
#      ------------------------ -------------- 7.9/12.8 MB 649.5 kB/s eta 0:00:08
#      ------------------------ -------------- 7.9/12.8 MB 650.3 kB/s eta 0:00:08
#      ------------------------ -------------- 8.0/12.8 MB 649.5 kB/s eta 0:00:08
#      ------------------------ -------------- 8.0/12.8 MB 647.9 kB/s eta 0:00:08
#      ------------------------ -------------- 8.0/12.8 MB 647.9 kB/s eta 0:00:08
#      ------------------------ -------------- 8.0/12.8 MB 646.2 kB/s eta 0:00:08
#      ------------------------ -------------- 8.0/12.8 MB 644.6 kB/s eta 0:00:08
#      ------------------------ -------------- 8.0/12.8 MB 644.6 kB/s eta 0:00:08
#      ------------------------ -------------- 8.0/12.8 MB 642.2 kB/s eta 0:00:08
#      ------------------------ -------------- 8.0/12.8 MB 642.2 kB/s eta 0:00:08
#      ------------------------ -------------- 8.1/12.8 MB 639.9 kB/s eta 0:00:08
#      ------------------------ -------------- 8.1/12.8 MB 639.9 kB/s eta 0:00:08
#      ------------------------ -------------- 8.1/12.8 MB 636.0 kB/s eta 0:00:08
#      ------------------------ -------------- 8.1/12.8 MB 634.5 kB/s eta 0:00:08
#      ------------------------ -------------- 8.1/12.8 MB 633.7 kB/s eta 0:00:08
#      ------------------------ -------------- 8.1/12.8 MB 632.2 kB/s eta 0:00:08
#      ------------------------ -------------- 8.1/12.8 MB 632.2 kB/s eta 0:00:08
#      ------------------------ -------------- 8.2/12.8 MB 629.2 kB/s eta 0:00:08
#      ------------------------ -------------- 8.2/12.8 MB 627.8 kB/s eta 0:00:08
#      ------------------------ -------------- 8.2/12.8 MB 626.3 kB/s eta 0:00:08
#      ------------------------ -------------- 8.2/12.8 MB 626.3 kB/s eta 0:00:08
#      ------------------------ -------------- 8.2/12.8 MB 622.7 kB/s eta 0:00:08
#      ------------------------- ------------- 8.2/12.8 MB 622.0 kB/s eta 0:00:08
#      ------------------------- ------------- 8.2/12.8 MB 619.8 kB/s eta 0:00:08
#      ------------------------- ------------- 8.2/12.8 MB 619.8 kB/s eta 0:00:08
#      ------------------------- ------------- 8.2/12.8 MB 619.8 kB/s eta 0:00:08
#      ------------------------- ------------- 8.3/12.8 MB 617.7 kB/s eta 0:00:08
#      ------------------------- ------------- 8.3/12.8 MB 617.7 kB/s eta 0:00:08
#      ------------------------- ------------- 8.3/12.8 MB 617.7 kB/s eta 0:00:08
#      ------------------------- ------------- 8.3/12.8 MB 617.7 kB/s eta 0:00:08
#      ------------------------- ------------- 8.3/12.8 MB 617.7 kB/s eta 0:00:08
#      ------------------------- ------------- 8.3/12.8 MB 617.7 kB/s eta 0:00:08
#      ------------------------- ------------- 8.3/12.8 MB 605.8 kB/s eta 0:00:08
#      ------------------------- ------------- 8.3/12.8 MB 605.8 kB/s eta 0:00:08
#      ------------------------- ------------- 8.3/12.8 MB 603.1 kB/s eta 0:00:08
#      ------------------------- ------------- 8.3/12.8 MB 603.1 kB/s eta 0:00:08
#      ------------------------- ------------- 8.3/12.8 MB 600.5 kB/s eta 0:00:08
#      ------------------------- ------------- 8.3/12.8 MB 600.5 kB/s eta 0:00:08
#      ------------------------- ------------- 8.3/12.8 MB 597.8 kB/s eta 0:00:08
#      ------------------------- ------------- 8.3/12.8 MB 597.8 kB/s eta 0:00:08
#      ------------------------- ------------- 8.3/12.8 MB 594.6 kB/s eta 0:00:08
#      ------------------------- ------------- 8.3/12.8 MB 594.1 kB/s eta 0:00:08
#      ------------------------- ------------- 8.3/12.8 MB 594.1 kB/s eta 0:00:08
#      ------------------------- ------------- 8.4/12.8 MB 591.5 kB/s eta 0:00:08
#      ------------------------- ------------- 8.4/12.8 MB 591.0 kB/s eta 0:00:08
#      ------------------------- ------------- 8.4/12.8 MB 591.0 kB/s eta 0:00:08
#      ------------------------- ------------- 8.4/12.8 MB 591.0 kB/s eta 0:00:08
#      ------------------------- ------------- 8.4/12.8 MB 587.3 kB/s eta 0:00:08
#      ------------------------- ------------- 8.4/12.8 MB 586.7 kB/s eta 0:00:08
#      ------------------------- ------------- 8.4/12.8 MB 586.7 kB/s eta 0:00:08
#      ------------------------- ------------- 8.4/12.8 MB 582.4 kB/s eta 0:00:08
#      ------------------------- ------------- 8.4/12.8 MB 582.4 kB/s eta 0:00:08
#      ------------------------- ------------- 8.4/12.8 MB 582.4 kB/s eta 0:00:08
#      ------------------------- ------------- 8.4/12.8 MB 578.1 kB/s eta 0:00:08
#      ------------------------- ------------- 8.4/12.8 MB 578.1 kB/s eta 0:00:08
#      ------------------------- ------------- 8.5/12.8 MB 576.4 kB/s eta 0:00:08
#      ------------------------- ------------- 8.5/12.8 MB 576.4 kB/s eta 0:00:08
#      ------------------------- ------------- 8.5/12.8 MB 574.7 kB/s eta 0:00:08
#      ------------------------- ------------- 8.5/12.8 MB 574.7 kB/s eta 0:00:08
#      ------------------------- ------------- 8.5/12.8 MB 572.4 kB/s eta 0:00:08
#      ------------------------- ------------- 8.5/12.8 MB 571.4 kB/s eta 0:00:08
#      ------------------------- ------------- 8.5/12.8 MB 571.4 kB/s eta 0:00:08
#      ------------------------- ------------- 8.5/12.8 MB 569.6 kB/s eta 0:00:08
#      ------------------------- ------------- 8.5/12.8 MB 569.6 kB/s eta 0:00:08
#      -------------------------- ------------ 8.5/12.8 MB 567.5 kB/s eta 0:00:08
#      -------------------------- ------------ 8.6/12.8 MB 567.1 kB/s eta 0:00:08
#      -------------------------- ------------ 8.6/12.8 MB 567.1 kB/s eta 0:00:08
#      -------------------------- ------------ 8.6/12.8 MB 567.1 kB/s eta 0:00:08
#      -------------------------- ------------ 8.6/12.8 MB 567.1 kB/s eta 0:00:08
#      -------------------------- ------------ 8.6/12.8 MB 567.1 kB/s eta 0:00:08
#      -------------------------- ------------ 8.6/12.8 MB 557.9 kB/s eta 0:00:08
#      -------------------------- ------------ 8.6/12.8 MB 558.0 kB/s eta 0:00:08
#      -------------------------- ------------ 8.6/12.8 MB 558.0 kB/s eta 0:00:08
#      -------------------------- ------------ 8.6/12.8 MB 556.0 kB/s eta 0:00:08
#      -------------------------- ------------ 8.6/12.8 MB 553.8 kB/s eta 0:00:08
#      -------------------------- ------------ 8.6/12.8 MB 554.0 kB/s eta 0:00:08
#      -------------------------- ------------ 8.7/12.8 MB 553.7 kB/s eta 0:00:08
#      -------------------------- ------------ 8.7/12.8 MB 552.7 kB/s eta 0:00:08
#      -------------------------- ------------ 8.7/12.8 MB 552.9 kB/s eta 0:00:08
#      -------------------------- ------------ 8.7/12.8 MB 552.4 kB/s eta 0:00:08
#      -------------------------- ------------ 8.7/12.8 MB 552.1 kB/s eta 0:00:08
#      -------------------------- ------------ 8.7/12.8 MB 551.3 kB/s eta 0:00:08
#      -------------------------- ------------ 8.8/12.8 MB 551.0 kB/s eta 0:00:08
#      -------------------------- ------------ 8.8/12.8 MB 551.0 kB/s eta 0:00:08
#      -------------------------- ------------ 8.8/12.8 MB 551.0 kB/s eta 0:00:08
#      -------------------------- ------------ 8.8/12.8 MB 547.8 kB/s eta 0:00:08
#      -------------------------- ------------ 8.8/12.8 MB 547.5 kB/s eta 0:00:08
#      -------------------------- ------------ 8.8/12.8 MB 547.4 kB/s eta 0:00:08
#      -------------------------- ------------ 8.9/12.8 MB 547.6 kB/s eta 0:00:08
#      --------------------------- ----------- 8.9/12.8 MB 547.4 kB/s eta 0:00:08
#      --------------------------- ----------- 8.9/12.8 MB 548.1 kB/s eta 0:00:08
#      --------------------------- ----------- 8.9/12.8 MB 547.9 kB/s eta 0:00:08
#      --------------------------- ----------- 9.0/12.8 MB 548.2 kB/s eta 0:00:07
#      --------------------------- ----------- 9.0/12.8 MB 548.4 kB/s eta 0:00:07
#      --------------------------- ----------- 9.0/12.8 MB 548.2 kB/s eta 0:00:07
#      --------------------------- ----------- 9.0/12.8 MB 548.9 kB/s eta 0:00:07
#      --------------------------- ----------- 9.1/12.8 MB 548.0 kB/s eta 0:00:07
#      --------------------------- ----------- 9.1/12.8 MB 547.9 kB/s eta 0:00:07
#      --------------------------- ----------- 9.1/12.8 MB 547.9 kB/s eta 0:00:07
#      --------------------------- ----------- 9.1/12.8 MB 546.1 kB/s eta 0:00:07
#      --------------------------- ----------- 9.1/12.8 MB 546.1 kB/s eta 0:00:07
#      --------------------------- ----------- 9.1/12.8 MB 545.8 kB/s eta 0:00:07
#      --------------------------- ----------- 9.1/12.8 MB 545.8 kB/s eta 0:00:07
#      --------------------------- ----------- 9.2/12.8 MB 543.6 kB/s eta 0:00:07
#      --------------------------- ----------- 9.2/12.8 MB 543.6 kB/s eta 0:00:07
#      ---------------------------- ---------- 9.2/12.8 MB 542.8 kB/s eta 0:00:07
#      ---------------------------- ---------- 9.2/12.8 MB 542.4 kB/s eta 0:00:07
#      ---------------------------- ---------- 9.2/12.8 MB 542.1 kB/s eta 0:00:07
#      ---------------------------- ---------- 9.2/12.8 MB 541.3 kB/s eta 0:00:07
#      ---------------------------- ---------- 9.3/12.8 MB 541.1 kB/s eta 0:00:07
#      ---------------------------- ---------- 9.3/12.8 MB 540.8 kB/s eta 0:00:07
#      ---------------------------- ---------- 9.3/12.8 MB 541.2 kB/s eta 0:00:07
#      ---------------------------- ---------- 9.3/12.8 MB 540.8 kB/s eta 0:00:07
#      ---------------------------- ---------- 9.3/12.8 MB 540.4 kB/s eta 0:00:07
#      ---------------------------- ---------- 9.4/12.8 MB 540.2 kB/s eta 0:00:07
#      ---------------------------- ---------- 9.4/12.8 MB 540.6 kB/s eta 0:00:07
#      ---------------------------- ---------- 9.4/12.8 MB 540.2 kB/s eta 0:00:07
#      ---------------------------- ---------- 9.5/12.8 MB 540.5 kB/s eta 0:00:07
#      ---------------------------- ---------- 9.5/12.8 MB 540.8 kB/s eta 0:00:07
#      ---------------------------- ---------- 9.5/12.8 MB 541.0 kB/s eta 0:00:07
#      ----------------------------- --------- 9.5/12.8 MB 540.8 kB/s eta 0:00:07
#      ----------------------------- --------- 9.6/12.8 MB 540.6 kB/s eta 0:00:06
#      ----------------------------- --------- 9.6/12.8 MB 541.3 kB/s eta 0:00:06
#      ----------------------------- --------- 9.6/12.8 MB 541.7 kB/s eta 0:00:06
#      ----------------------------- --------- 9.7/12.8 MB 542.0 kB/s eta 0:00:06
#      ----------------------------- --------- 9.7/12.8 MB 542.3 kB/s eta 0:00:06
#      ----------------------------- --------- 9.7/12.8 MB 542.6 kB/s eta 0:00:06
#      ----------------------------- --------- 9.7/12.8 MB 542.9 kB/s eta 0:00:06
#      ----------------------------- --------- 9.8/12.8 MB 543.3 kB/s eta 0:00:06
#      ----------------------------- --------- 9.8/12.8 MB 544.1 kB/s eta 0:00:06
#      ------------------------------ -------- 9.9/12.8 MB 544.8 kB/s eta 0:00:06
#      ------------------------------ -------- 9.9/12.8 MB 544.6 kB/s eta 0:00:06
#      ------------------------------ -------- 9.9/12.8 MB 545.4 kB/s eta 0:00:06
#      ------------------------------ -------- 9.9/12.8 MB 546.1 kB/s eta 0:00:06
#      ----------------------------- -------- 10.0/12.8 MB 546.4 kB/s eta 0:00:06
#      ----------------------------- -------- 10.0/12.8 MB 546.1 kB/s eta 0:00:06
#      ----------------------------- -------- 10.0/12.8 MB 547.1 kB/s eta 0:00:06
#      ----------------------------- -------- 10.1/12.8 MB 547.8 kB/s eta 0:00:05
#      ------------------------------ ------- 10.1/12.8 MB 548.7 kB/s eta 0:00:05
#      ------------------------------ ------- 10.2/12.8 MB 549.5 kB/s eta 0:00:05
#      ------------------------------ ------- 10.2/12.8 MB 550.4 kB/s eta 0:00:05
#      ------------------------------ ------- 10.3/12.8 MB 551.1 kB/s eta 0:00:05
#      ------------------------------ ------- 10.3/12.8 MB 551.1 kB/s eta 0:00:05
#      ------------------------------ ------- 10.3/12.8 MB 550.2 kB/s eta 0:00:05
#      ------------------------------ ------- 10.4/12.8 MB 548.8 kB/s eta 0:00:05
#      ------------------------------ ------- 10.4/12.8 MB 548.8 kB/s eta 0:00:05
#      ------------------------------ ------- 10.4/12.8 MB 549.7 kB/s eta 0:00:05
#      ------------------------------- ------ 10.5/12.8 MB 550.2 kB/s eta 0:00:05
#      ------------------------------- ------ 10.6/12.8 MB 549.2 kB/s eta 0:00:05
#      ------------------------------- ------ 10.6/12.8 MB 549.2 kB/s eta 0:00:05
#      ------------------------------- ------ 10.6/12.8 MB 548.8 kB/s eta 0:00:04
#      ------------------------------- ------ 10.6/12.8 MB 548.8 kB/s eta 0:00:04
#      ------------------------------- ------ 10.7/12.8 MB 547.9 kB/s eta 0:00:04
#      ------------------------------- ------ 10.7/12.8 MB 547.4 kB/s eta 0:00:04
#      ------------------------------- ------ 10.8/12.8 MB 546.9 kB/s eta 0:00:04
#      -------------------------------- ----- 10.8/12.8 MB 546.5 kB/s eta 0:00:04
#      -------------------------------- ----- 10.8/12.8 MB 545.6 kB/s eta 0:00:04
#      -------------------------------- ----- 10.8/12.8 MB 545.6 kB/s eta 0:00:04
#      -------------------------------- ----- 10.9/12.8 MB 546.1 kB/s eta 0:00:04
#      -------------------------------- ----- 10.9/12.8 MB 545.2 kB/s eta 0:00:04
#      -------------------------------- ----- 10.9/12.8 MB 544.2 kB/s eta 0:00:04
#      -------------------------------- ----- 10.9/12.8 MB 543.3 kB/s eta 0:00:04
#      -------------------------------- ----- 11.0/12.8 MB 542.4 kB/s eta 0:00:04
#      -------------------------------- ----- 11.0/12.8 MB 541.5 kB/s eta 0:00:04
#      -------------------------------- ----- 11.0/12.8 MB 542.4 kB/s eta 0:00:04
#      -------------------------------- ----- 11.1/12.8 MB 541.5 kB/s eta 0:00:04
#      -------------------------------- ----- 11.1/12.8 MB 541.5 kB/s eta 0:00:04
#      -------------------------------- ----- 11.1/12.8 MB 541.1 kB/s eta 0:00:04
#      --------------------------------- ---- 11.1/12.8 MB 540.6 kB/s eta 0:00:04
#      --------------------------------- ---- 11.2/12.8 MB 540.2 kB/s eta 0:00:04
#      --------------------------------- ---- 11.2/12.8 MB 539.3 kB/s eta 0:00:04
#      --------------------------------- ---- 11.2/12.8 MB 539.3 kB/s eta 0:00:03
#      --------------------------------- ---- 11.2/12.8 MB 538.8 kB/s eta 0:00:03
#      --------------------------------- ---- 11.3/12.8 MB 538.0 kB/s eta 0:00:03
#      --------------------------------- ---- 11.3/12.8 MB 537.5 kB/s eta 0:00:03
#      --------------------------------- ---- 11.3/12.8 MB 537.5 kB/s eta 0:00:03
#      --------------------------------- ---- 11.4/12.8 MB 538.0 kB/s eta 0:00:03
#      --------------------------------- ---- 11.4/12.8 MB 537.1 kB/s eta 0:00:03
#      --------------------------------- ---- 11.4/12.8 MB 537.5 kB/s eta 0:00:03
#      ---------------------------------- --- 11.5/12.8 MB 537.1 kB/s eta 0:00:03
#      ---------------------------------- --- 11.5/12.8 MB 537.1 kB/s eta 0:00:03
#      ---------------------------------- --- 11.5/12.8 MB 536.2 kB/s eta 0:00:03
#      ---------------------------------- --- 11.6/12.8 MB 536.6 kB/s eta 0:00:03
#      ---------------------------------- --- 11.6/12.8 MB 536.2 kB/s eta 0:00:03
#      ---------------------------------- --- 11.6/12.8 MB 535.8 kB/s eta 0:00:03
#      ---------------------------------- --- 11.7/12.8 MB 535.8 kB/s eta 0:00:03
#      ---------------------------------- --- 11.7/12.8 MB 535.8 kB/s eta 0:00:03
#      ---------------------------------- --- 11.7/12.8 MB 535.3 kB/s eta 0:00:02
#      ---------------------------------- --- 11.8/12.8 MB 534.9 kB/s eta 0:00:02
#      ----------------------------------- -- 11.8/12.8 MB 535.8 kB/s eta 0:00:02
#      ----------------------------------- -- 11.9/12.8 MB 534.9 kB/s eta 0:00:02
#      ----------------------------------- -- 11.9/12.8 MB 535.3 kB/s eta 0:00:02
#      ----------------------------------- -- 11.9/12.8 MB 534.9 kB/s eta 0:00:02
#      ----------------------------------- -- 11.9/12.8 MB 534.5 kB/s eta 0:00:02
#      ----------------------------------- -- 12.0/12.8 MB 534.5 kB/s eta 0:00:02
#      ----------------------------------- -- 12.0/12.8 MB 534.4 kB/s eta 0:00:02
#      ----------------------------------- -- 12.0/12.8 MB 534.5 kB/s eta 0:00:02
#      ----------------------------------- -- 12.1/12.8 MB 534.0 kB/s eta 0:00:02
#      ----------------------------------- -- 12.1/12.8 MB 534.0 kB/s eta 0:00:02
#      ------------------------------------ - 12.1/12.8 MB 533.6 kB/s eta 0:00:02
#      ------------------------------------ - 12.2/12.8 MB 533.6 kB/s eta 0:00:02
#      ------------------------------------ - 12.2/12.8 MB 533.2 kB/s eta 0:00:02
#      ------------------------------------ - 12.2/12.8 MB 533.1 kB/s eta 0:00:02
#      ------------------------------------ - 12.3/12.8 MB 532.7 kB/s eta 0:00:01
#      ------------------------------------ - 12.3/12.8 MB 532.7 kB/s eta 0:00:01
#      ------------------------------------ - 12.4/12.8 MB 532.7 kB/s eta 0:00:01
#      ------------------------------------ - 12.4/12.8 MB 533.1 kB/s eta 0:00:01
#      ------------------------------------ - 12.5/12.8 MB 532.7 kB/s eta 0:00:01
#      -------------------------------------  12.5/12.8 MB 532.7 kB/s eta 0:00:01
#      -------------------------------------  12.5/12.8 MB 533.6 kB/s eta 0:00:01
#      -------------------------------------  12.6/12.8 MB 533.1 kB/s eta 0:00:01
#      -------------------------------------  12.6/12.8 MB 533.6 kB/s eta 0:00:01
#      -------------------------------------  12.7/12.8 MB 532.7 kB/s eta 0:00:01
#      -------------------------------------  12.7/12.8 MB 532.3 kB/s eta 0:00:01
#      -------------------------------------  12.7/12.8 MB 532.3 kB/s eta 0:00:01
#      -------------------------------------  12.7/12.8 MB 532.7 kB/s eta 0:00:01
#      -------------------------------------  12.8/12.8 MB 532.3 kB/s eta 0:00:01
#      -------------------------------------  12.8/12.8 MB 531.4 kB/s eta 0:00:01
#      -------------------------------------- 12.8/12.8 MB 530.3 kB/s eta 0:00:00
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

doc = nlp("I'm enjoying the NLP course!")

for token in doc:
    print(token)
# Out:
# I
# 'm
# enjoying
# the
# NLP
# course
# !

# %%
text = "A 5km NYC cab ride costs $10.30"
doc = nlp("A 5km NYC cab ride costs $10.30")
print('nltk', nltk.word_tokenize(text))

print('##############################')
for token in doc:
    print(token)
# Out:
# nltk ['A', '5km', 'NYC', 'cab', 'ride', 'costs', '$', '10.30']
# ##############################
# A
# 5
# km
# NYC
# cab
# ride
# costs
# $
# 10.30

# %% [markdown]
# ### Lower Casting

# %% [markdown]
# Converting a word to lower case (NLP -> nlp). Words like Book and book mean the same but when not converted to the lower case those two are represented as two different words in the vector space model (resulting in more dimensions).

# %%
text = "I'm enjoying the NLP course!"
text = text.lower()
text
# Out:
# "i'm enjoying the nlp course!"

# %% [markdown]
# ### Stemming

# %% [markdown]
# Stemming is basically removing the suffix from a word and reduce it to its root word. For example: “Flying” is a word and its suffix is “ing”, if we remove “ing” from “Flying” then we will get base word or root word which is “Fly”. We uses these suffix to create a new word from original stem word.

# %% [markdown]
# https://www.nltk.org/howto/stem.html

# %% [markdown]
# #### What is PorterStemmer?
#
# It is one of the most popular stemming methods proposed in 1980. It is based on the idea that the suffixes in the English language are made up of a combination of smaller and simpler suffixes. This stemmer is known for its speed and simplicity. The main applications of Porter Stemmer include data mining and Information retrieval. However, its applications are only limited to English words. Also, the group of stems is mapped on to the same stem and the output stem is not necessarily a meaningful word. The algorithms are fairly lengthy in nature and are known to be the oldest stemmer.
#
# > Advantage: It produces the best output as compared to other stemmers and it has less error rate.
#
# > Limitation:  Morphological variants produced are not always real words.

# %%
import nltk
from nltk.stem import PorterStemmer

ps = PorterStemmer()

words = ['run','runner','running','ran','runs','easily','fairly']

for word in words:
    print(word + ' --> ' + ps.stem(word))
# Out:
# run --> run
# runner --> runner
# running --> run
# ran --> ran
# runs --> run
# easily --> easili
# fairly --> fairli

# %% [markdown]
# #### What is SnowballStemmer?
#
# It is a stemming algorithm which is also known as the Porter2 stemming algorithm as it is a better version of the Porter Stemmer since some issues of it were fixed in this stemmer.
#
# > Advantage: It is slightly faster computation time than porter, with a reasonably large community around it.

# %%
import nltk
from nltk.stem.snowball import SnowballStemmer

sn = SnowballStemmer(language='english')

words = ['run','runner','running','ran','runs','easily','fairly']

for word in words:
    print(word+' --> '+sn.stem(word))
# Out:
# run --> run
# runner --> runner
# running --> run
# ran --> ran
# runs --> run
# easily --> easili
# fairly --> fair

# %% [markdown]
# #### Comparing between porter and snowball

# %%
words = ['generous','generation','generously','generate']

for word in words:
    print(word+' --> '+ps.stem(word))
    print(word+' --> '+sn.stem(word))
    print('---------------------------------------')
# Out:
# generous --> gener
# generous --> generous
# ---------------------------------------
# generation --> gener
# generation --> generat
# ---------------------------------------
# generously --> gener
# generously --> generous
# ---------------------------------------
# generate --> gener
# generate --> generat
# ---------------------------------------

# %% [markdown]
# **Note**: Spacy does not provide stemming

# %% [markdown]
# ### Lemmatization

# %% [markdown]
# Lemmatization is the process of grouping together the different inflected forms of a word so they can be analyzed as a single item. Lemmatization is similar to stemming but it brings context to the words. So it links words with similar meanings to one word.
#
# > One major difference with stemming is that lemmatize takes a part of speech parameter, “pos” If not supplied, the default is “noun.”

# %%
import nltk
from nltk.stem import WordNetLemmatizer

text = 'I am enjoying with AI courses. I am taking NLP course.'
lemmatizer = WordNetLemmatizer()

for word in nltk.word_tokenize(text):
    nltk.download('wordnet', quiet=True)
    nltk.download('omw-1.4', quiet=True)

    for word in nltk.word_tokenize(text):
        print(f"{word}: ", lemmatizer.lemmatize(word))
# Out:
# I:  I
# am:  am
# enjoying:  enjoying
# with:  with
# AI:  AI
# courses:  course
# .:  .
# I:  I
# am:  am
# taking:  taking
# NLP:  NLP
# course:  course
# .:  .
# I:  I
# am:  am
# enjoying:  enjoying
# with:  with
# AI:  AI
# courses:  course
# .:  .
# I:  I
# am:  am
# taking:  taking
# NLP:  NLP
# course:  course
# .:  .
# I:  I
# am:  am
# enjoying:  enjoying
# with:  with
# AI:  AI
# courses:  course
# .:  .
# I:  I
# am:  am
# taking:  taking
# NLP:  NLP
# course:  course
# .:  .
# I:  I
# am:  am
# enjoying:  enjoying
# with:  with
# AI:  AI
# courses:  course
# .:  .
# I:  I
# am:  am
# taking:  taking
# NLP:  NLP
# course:  course
# .:  .
# I:  I
# am:  am
# enjoying:  enjoying
# with:  with
# AI:  AI
# courses:  course
# .:  .
# I:  I
# am:  am
# taking:  taking
# NLP:  NLP
# course:  course
# .:  .
# I:  I
# am:  am
# enjoying:  enjoying
# with:  with
# AI:  AI
# courses:  course
# .:  .
# I:  I
# am:  am
# taking:  taking
# NLP:  NLP
# course:  course
# .:  .
# I:  I
# am:  am
# enjoying:  enjoying
# with:  with
# AI:  AI
# courses:  course
# .:  .
# I:  I
# am:  am
# taking:  taking
# NLP:  NLP
# course:  course
# .:  .
# I:  I
# am:  am
# enjoying:  enjoying
# with:  with
# AI:  AI
# courses:  course
# .:  .
# I:  I
# am:  am
# taking:  taking
# NLP:  NLP
# course:  course
# .:  .
# I:  I
# am:  am
# enjoying:  enjoying
# with:  with
# AI:  AI
# courses:  course
# .:  .
# I:  I
# am:  am
# taking:  taking
# NLP:  NLP
# course:  course
# .:  .
# I:  I
# am:  am
# enjoying:  enjoying
# with:  with
# AI:  AI
# courses:  course
# .:  .
# I:  I
# am:  am
# taking:  taking
# NLP:  NLP
# course:  course
# .:  .
# I:  I
# am:  am
# enjoying:  enjoying
# with:  with
# AI:  AI
# courses:  course
# .:  .
# I:  I
# am:  am
# taking:  taking
# NLP:  NLP
# course:  course
# .:  .
# I:  I
# am:  am
# enjoying:  enjoying
# with:  with
# AI:  AI
# courses:  course
# .:  .
# I:  I
# am:  am
# taking:  taking
# NLP:  NLP
# course:  course
# .:  .
# I:  I
# am:  am
# enjoying:  enjoying
# with:  with
# AI:  AI
# courses:  course
# .:  .
# I:  I
# am:  am
# taking:  taking
# NLP:  NLP
# course:  course
# .:  .

# %% [markdown]
# You may go through Spacy's lemmatizer: https://spacy.io/api/lemmatizer

# %% [markdown]
# ### ٍStop Words Removal

# %% [markdown]
# The words which are generally filtered out before processing a natural language are called stop words. These are actually the most common words in any language (like articles, prepositions, pronouns, conjunctions, etc) and does not add much information to the text. Examples of a few stop words in English are “the”, “a”, “an”, “so”, “what”.

# %% [markdown]
# #### Why do we need to remove stopwords?

# %% [markdown]
# By removing these words, we remove the low-level information from our text in order to give more focus to the important information. In order words, we can say that the removal of such words does not show any negative consequences on the model we train for our task.
#
# - reduces the dataset size
# - reduces the training time

# %% [markdown]
# #### Do we always remove stopwords? **NO!**

# %% [markdown]
# We do not always remove the stop words. The removal of stop words is highly dependent on the task we are performing and the goal we want to achieve. For example, if we are training a model that can perform the sentiment analysis task, we might not remove the stop words.
#
# Movie review: “The movie was not good at all.”
#
# Text after removal of stop words: “movie good”

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'mostly', 'if', 'through', 'often', 'afterwards', 'beside', 'must', 'should', 'own', '‘s', 'other', "'s", 'were', 'full', 'fifty', 'thus', 'whoever', 'until', 'amongst', 'onto', 'ours', 'go', 'also', 'forty', 'seemed', 'formerly', 'here', 'much', 'while', 'on', 'thence', 'after', 'latterly', 'along', 'as', 'really', '’d', "'m", 'part', 'without', 'except', 'almost', 'he', '‘d', 'two', 'many', 'noone', 'where', 'wherein', 'get', 'somehow', 'something', 'again', 'beyond', 'back', 'in', 'when', 'across', "'d", 'make', 'might', 'eight', 'hundred', 'under', 'seems', 'whither', 'take', 'whence', 'can', 'give', 'his', '’re', 'every', 'am', 'from', 'yours', 'yet', 'elsewhere', 'neither', 'anyway', 'sometime', 'first', 'below', 'down', 'moreover', 'keep', 'whom', 'anyhow', 'nowhere', 'never', 'together', 'some', 'that', 'nor', 'was', 'their', 'are', 'out', 'during', 'becoming', 'been', '’s', 'the', 'be', 'front', 'amount', 'above', "'re", 'rather', 'each', 'whereafter', 'yourself', 'ten', 'or', 'whenever', 'throughout', 'would', 'empty', 'you', 'them', 'mine', 'around', 'so', 'due', '‘ve', 'someone', 'to', 'further', 'everyone', 'none', 'how', 'indeed', 'a', 'various', 'had', 'per', 'three', 'top', 'ca', '‘m', 'quite', 'is', 'show', 'last', 'whole', 'ever', 'herself', 'one', 'several', 'nobody', 'see', 'even', 'used', 'hence', '‘re', 'him', 'always', 'behind', 'more', 'doing', 'therein', 'already', 'thru', 'all', 'very', 'why', 'nine', 'everywhere', 'else', 'hereupon', 'both', 'fifteen', 'it', 'others', 'either', 'another', 'against', 'whose', 'i', 'six', 'do', 'thereupon', 'yourselves', 'upon', 'sixty', 'these', 'too', 'did', '‘ll', 'an', 'via', 'few', 'because', 'beforehand', 'itself', 'and', 'before', 'whether', "'ve", 'most', 'no', 'seem', 'enough', 'into', 'made', 'bottom', 'which', 'although', 'nothing', 'next', 'therefore', 'sometimes', '’m', 'have', 'at', 'now', 'twelve', 'former', 'otherwise', 'cannot', 'meanwhile', 'becomes', 'herein', 'could', 'up', 'namely', 'name', 'me', "n't", 'wherever', 'over', 'what', 'since', 'side', 'with', 'became', 'well', 'has', "'ll", 'using', 'please', 'whereas', 'hereafter', 'whatever', 'anyone', 'become', '’ll', 'twenty', 'everything', 'nevertheless', 'being', 'perhaps', 'whereby', 'themselves', 'she', 'within', 'of', 'move', 'call', 'once', 'does', '’ve', 'same', 'towards', 'such', 'myself', 'besides', 'serious', 'seeming', 'any', 'put', 'will', 'thereby', 'among', 'latter', 'then', 'her', 'n‘t', 'about', 'my', 'hereby', 'regarding', 'n’t', 'ourselves', 'this', 'toward', 'we', 'but', 'unless', 'still', 'only', 'may', 'done', 'who', 'though', 'between', 'say', 'your', 're', 'alone', 'least', 'less', 'our', 'eleven', 'anything', 'its', 'those', 'they', 'anywhere', 'than', 'just', 'somewhere', 'however', 'third', 'thereafter', 'not', 'off', 'there', 'us', 'for', 'five', 'hers', 'whereupon', 'by', 'four', 'himself'}

# %%
print(nlp.vocab['myself'].is_stop)
print(nlp.vocab['mystery'].is_stop)
# Out:
# True
# False

# %%
nlp.Defaults.stop_words.add('btw')
print (nlp.vocab['btw'].is_stop)
# Out:
# True

# %%
nlp.Defaults.stop_words.remove('beyond')
nlp.vocab['beyond'].is_stop = False

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dania\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))
print(len(stop_words))
stop_words
# Out:
# 198
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %% [markdown]
# _________________________________________________________________________________________________________

# %% [markdown]
# # Text pre-processing Example

# %% [markdown]
# To make you understand better about the need of text pre-processing. We will do a small project. In this project, I need to find how many hashtags and the top 10 hashtags used in the dataset.
#
# The dataset is about people tweets about apple company in the twitter. You can find the dataset here: https://www.kaggle.com/datasets/seriousran/appletwittersentimenttexts
#
# Output labels:
#
# - -1: negative
# - 0: neutral
# - 1: positive

# %% [markdown]
# ### Step 1: Load the dataset
#
# We load the Apple Twitter Sentiment dataset

# %%
import pandas as pd
import re
from collections import Counter

df = pd.read_csv('apple-twitter-sentiment-texts.csv')
df['text'] = df['text'].astype(str)  # make sure everything is treated as string

print("Shape of dataset:", df.shape)
df.head()
# Out:
# Shape of dataset: (1630, 2)
#                                                 text  sentiment
# 0  Wow. Yall needa step it up @Apple RT @heynyla:...         -1
# 1  What Happened To Apple Inc?   http://t.co/FJEX...          0
# 2  Thank u @apple I can now compile all of the pi...          1
# 3  The oddly uplifting story of the Apple co-foun...          0
# 4  @apple can i exchange my iphone for a differen...          0

# %% [markdown]
# ### Step 2: Inspect a few raw tweets
#
# Before writing our regex, let's look at what a hashtag looks like inside a real tweet.

# %%
for tweet in df['text'].head(5):
    print(tweet)
    print('-'*80)
# Out:
# Wow. Yall needa step it up @Apple RT @heynyla: Music and snapchat at the same damn time. Thank you #Note4
# --------------------------------------------------------------------------------
# What Happened To Apple Inc?   http://t.co/FJEXI3oP0U  #aapl #apple @MoneyPress http://t.co/wXKmmTMArW
# --------------------------------------------------------------------------------
# Thank u @apple I can now compile all of the pics that i communicate with in one place http://t.co/tq1lo09oyA
# --------------------------------------------------------------------------------
# The oddly uplifting story of the Apple co-founder who sold his stake for $800
# $AAPL #aapl
# http://t.co/CiZbVR05PJ
# --------------------------------------------------------------------------------
# @apple can i exchange my iphone for a different color lmao  i changed my mind
# --------------------------------------------------------------------------------

# %% [markdown]
# ### Step 3: Build a regular expression to extract hashtags
#
#
# - `#` matches the literal hashtag symbol
# - `\w+` matches one or more alphanumeric/underscore characters right after it

# %%
hashtag_pattern = re.compile(r"#\w+")

# quick sanity check on a single tweet
sample = "What Happened To Apple Inc?   http://t.co/FJEXI3oP0U  #aapl #apple @MoneyPress"
print(hashtag_pattern.findall(sample))
# Out:
# ['#aapl', '#apple']

# %% [markdown]
# ### Step 4: Extract hashtags from every tweet
#
# We apply `findall` to the `text` column so that each row gets a list of the hashtags it contains (an empty list if it has none).

# %%
df['hashtags'] = df['text'].apply(lambda tweet: hashtag_pattern.findall(tweet))

df[['text', 'hashtags']].head(10)
# Out:
#                                                 text         hashtags
# 0  Wow. Yall needa step it up @Apple RT @heynyla:...         [#Note4]
# 1  What Happened To Apple Inc?   http://t.co/FJEX...  [#aapl, #apple]
# 2  Thank u @apple I can now compile all of the pi...               []
# 3  The oddly uplifting story of the Apple co-foun...          [#aapl]
# 4  @apple can i exchange my iphone for a differen...               []
# 5  RT @JPDesloges: Apple Acted Unfairly In Suppre...          [#aapl]
# 6  Let's not forget that press effects stock @App...               []
# 7  Apple Inc. Deleted Songs From Rival Services F...          [#AAPL]
# 8  @TeamCavuto @Apple They're staging a die in ar...               []
# 9  Happy Monday! My camera on my fancy @Apple #iP...   [#iPhone6Plus]

# %% [markdown]
# ### Step 5: Pre-process the extracted hashtags
#
# Before counting, we apply a small text pre-processing step: **lower-casing**. This matters because `#Apple`, `#apple`, and `#APPLE` should all be counted as the same hashtag — otherwise we would be treating identical hashtags as different tokens, exactly the same problem lower-casing solves for regular words.

# %%
# Flatten the list of lists into one big list of hashtags, lower-cased
all_hashtags = [tag.lower() for tags in df['hashtags'] for tag in tags]

print("First 10 extracted hashtags:", all_hashtags[:10])
# Out:
# First 10 extracted hashtags: ['#note4', '#aapl', '#apple', '#aapl', '#aapl', '#aapl', '#iphone6plus', '#aapl', '#apple', '#skyworks']

# %% [markdown]
# ### Step 6: Total number of hashtags
#
# This is simply the length of the flattened list — i.e., how many hashtag occurrences appear across the whole dataset (a tweet using `#aapl` twice counts twice).

# %%
total_hashtags = len(all_hashtags)
unique_hashtags = len(set(all_hashtags))

print(f"Total number of hashtags in the dataset: {total_hashtags}")
print(f"Number of unique hashtags: {unique_hashtags}")
# Out:
# Total number of hashtags in the dataset: 1616
# Number of unique hashtags: 555

# %% [markdown]
# ### Step 7: Top 10 most frequently used hashtags
#
# We use `collections.Counter` to count how many times each hashtag appears, then use `.most_common(10)` to get the 10 most frequent ones.

# %%
hashtag_counts = Counter(all_hashtags)

top_10_hashtags = hashtag_counts.most_common(10)

print("Top 10 most frequent hashtags:\n")
for rank, (tag, count) in enumerate(top_10_hashtags, start=1):
    print(f"{rank:>2}. {tag:<15} -> {count} times")
# Out:
# Top 10 most frequent hashtags:
#
#  1. #aapl           -> 400 times
#  2. #apple          -> 162 times
#  3. #iphone         -> 38 times
#  4. #december       -> 37 times
#  5. #iphone6        -> 29 times
#  6. #stocks         -> 15 times
#  7. #ipad           -> 14 times
#  8. #iphone6plus    -> 13 times
#  9. #iphone6s       -> 13 times
# 10. #tech           -> 12 times

# %% [markdown]
# ### Step 8: Visualize the top 10 hashtags
#
# A quick bar chart makes the relative popularity of each hashtag easy to see at a glance.

# %%
import matplotlib.pyplot as plt

tags, counts = zip(*top_10_hashtags)

plt.figure(figsize=(10, 5))
plt.bar(tags, counts, color='steelblue')
plt.xlabel('Hashtag')
plt.ylabel('Frequency')
plt.title('Top 10 Most Frequently Used Hashtags (Apple Twitter Dataset)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Conclusion
#
# Using the regular expression `#\w+`, we were able to reliably extract every hashtag from the raw, noisy tweet text (which also contained mentions, URLs, and retweet markers) without needing to run the full pre-processing pipeline (tokenization, stemming, lemmatization, stop-word removal) described earlier in this lab. This shows how a well designed regex can be a lightweight but powerful feature extraction tool in NLP, especially for structured tokens like hashtags, mentions, and URLs that don't need to be broken further down.
